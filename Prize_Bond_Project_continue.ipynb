# %% [markdown]
# <a href="https://colab.research.google.com/github/zohaib479/Data-Science-Project/blob/main/Prize_Bond_Project_continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("3rd-prize-750draw-102.csv", header=None)
df.head()
# Out:
#       0       1      2      3
# 0   670     NaN   2057   2107
# 1  2566  3380.0   4049   4228
# 2  4323  4479.0   4954   6781
# 3  7490  7543.0   8584   8839
# 4  8935  9713.0  10307  10509

# %%
array_1D = df.to_numpy().flatten()
array_1D
# Out:
# array([6.70000e+02,         nan, 2.05700e+03, ..., 9.98333e+05,
#        9.98935e+05, 9.99584e+05])

# %%
new_df = pd.DataFrame(array_1D, columns=["Wiining_Prize_Nums"])
new_df.head()
# Out:
#    Wiining_Prize_Nums
# 0               670.0
# 1                 NaN
# 2              2057.0
# 3              2107.0
# 4              2566.0

# %%
print(type(new_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
new_df["Wiining_Prize_Nums"] = new_df["Wiining_Prize_Nums"].astype(str)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1696 entries, 0 to 1695
# Data columns (total 1 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wiining_Prize_Nums  1696 non-null   object
# dtypes: object(1)
# memory usage: 13.4+ KB

# %%
lst = []
for i in new_df["Wiining_Prize_Nums"]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

# %%
new_df["NEW_COL"] = lst
new_df.drop(columns=["Wiining_Prize_Nums"], inplace=True, axis=1)
new_df.head()
# Out:
#   NEW_COL
# 0  0670.0
# 1  000nan
# 2  2057.0
# 3  2107.0
# 4  2566.0

# %%
print(type(new_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
new_df["Draw_Num"] = 102

# %%
new_df.head()
# Out:
#   NEW_COL  Draw_Num
# 0  0670.0       102
# 1  000nan       102
# 2  2057.0       102
# 3  2107.0       102
# 4  2566.0       102

# %%
df_firstPrize=pd.DataFrame([261227],columns=['First_Winning_Prize'])

# %%
print(type(df_firstPrize))
df_firstPrize["Draw_Num"] = 102
df_firstPrize
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102

# %%
df_SecondPrize=pd.DataFrame([204763,413549,992747],columns=['Second_Winning_prize'])

# %%
print(type(df_SecondPrize))
df_SecondPrize["Draw_Num"] = 102
df_SecondPrize
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Second_Winning_prize  Draw_Num
# 0                204763       102
# 1                413549       102
# 2                992747       102

# %%
df_101_3rd=pd.read_csv('101_LIST.csv',header=None)

# %%
array2=df_101_3rd.to_numpy().flatten()
array2
# Out:
# array([   164,    314,   1164, ..., 999780, 999784, 999867])

# %%
df_temp=pd.DataFrame(array2)

# %%
def converter(df,col):
  df[col] = df[col].astype(str)
  return df

# %%
converter(df_temp,0)
# Out:
#            0
# 0        164
# 1        314
# 2       1164
# 3       1480
# 4       2432
# ...      ...
# 1691  999206
# 1692  999578
# 1693  999780
# 1694  999784
# 1695  999867
#
# [1696 rows x 1 columns]

# %%
df_temp
# Out:
#            0
# 0        164
# 1        314
# 2       1164
# 3       1480
# 4       2432
# ...      ...
# 1691  999206
# 1692  999578
# 1693  999780
# 1694  999784
# 1695  999867
#
# [1696 rows x 1 columns]

# %%
lst = []
for i in df_temp[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

# %%
df_temp["NEW_COL"]=lst

# %%
df_temp.drop(columns=[0],inplace=True,axis=1)

# %%
df_temp
# Out:
#      NEW_COL
# 0     000164
# 1     000314
# 2     001164
# 3     001480
# 4     002432
# ...      ...
# 1691  999206
# 1692  999578
# 1693  999780
# 1694  999784
# 1695  999867
#
# [1696 rows x 1 columns]

# %%
df_temp["Draw_Num"] = 101

# %%
new_dff = pd.concat([new_df,df_temp])
new_dff.tail(10)
# Out:
#      NEW_COL  Draw_Num
# 1686  993388       101
# 1687  993481       101
# 1688  995098       101
# 1689  995678       101
# 1690  997199       101
# 1691  999206       101
# 1692  999578       101
# 1693  999780       101
# 1694  999784       101
# 1695  999867       101

# %%
df_SecondPrize101=pd.DataFrame([317904,496553,800663],columns=['Second_Winning_prize'])
print(type(df_SecondPrize))
df_SecondPrize101["Draw_Num"] = 101
df_SecondPrize101
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Second_Winning_prize  Draw_Num
# 0                317904       101
# 1                496553       101
# 2                800663       101

# %%
new_dff2ndPrize=pd.concat([df_SecondPrize,df_SecondPrize101])
new_dff2ndPrize
# Out:
#    Second_Winning_prize  Draw_Num
# 0                204763       102
# 1                413549       102
# 2                992747       102
# 0                317904       101
# 1                496553       101
# 2                800663       101

# %%
df_1st_temp=pd.DataFrame([271541],columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 101
df_1st_temp
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               271541       101

# %%
new_dff1stprize=pd.concat([df_firstPrize,df_1st_temp])
new_dff1stprize
# Out:
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 0               271541       101

# %%
df_100_3rd=pd.read_csv('100-3rd-prze.csv',header=None)
df_100_3rd
# Out:
#           0       1       2       3
# 0       304     653    1013    1422
# 1      1688    3375    3475    3496
# 2      3647    6130    6300    6530
# 3      7477    7814    8170    8299
# 4      8366    8389    8665   10657
# ..      ...     ...     ...     ...
# 419  992667  992932  993380  994025
# 420  994300  995136  995405  996444
# 421  997004  997178  997362  997471
# 422  997511  997520  998124  998540
# 423  999276  999552  999599  999788
#
# [424 rows x 4 columns]

# %%
array3 = df_100_3rd.to_numpy().flatten()
df_tempp = pd.DataFrame(array3)
df_tempp
# Out:
#            0
# 0        304
# 1        653
# 2       1013
# 3       1422
# 4       1688
# ...      ...
# 1691  998540
# 1692  999276
# 1693  999552
# 1694  999599
# 1695  999788
#
# [1696 rows x 1 columns]

# %%
df_tempp
# Out:
#            0
# 0        304
# 1        653
# 2       1013
# 3       1422
# 4       1688
# ...      ...
# 1691  998540
# 1692  999276
# 1693  999552
# 1694  999599
# 1695  999788
#
# [1696 rows x 1 columns]

# %%
df_tempp[0] = df_tempp[0].astype(str)

# %%
lst = []
for i in df_tempp[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_tempp["NEW_COL"]=lst

# %%
df_tempp.drop(columns=[0],inplace=True,axis=1)

# %%
df_tempp
# Out:
#      NEW_COL
# 0     000304
# 1     000653
# 2     001013
# 3     001422
# 4     001688
# ...      ...
# 1691  998540
# 1692  999276
# 1693  999552
# 1694  999599
# 1695  999788
#
# [1696 rows x 1 columns]

# %%
df_tempp["Draw_Num"] = 100

# %%
new_dfff = pd.concat([new_dff, df_tempp])
new_dfff.head(10)
# Out:
#   NEW_COL  Draw_Num
# 0  0670.0       102
# 1  000nan       102
# 2  2057.0       102
# 3  2107.0       102
# 4  2566.0       102
# 5  3380.0       102
# 6  4049.0       102
# 7  4228.0       102
# 8  4323.0       102
# 9  4479.0       102

# %%
# Process 2nd prize
df_SecondPrize100 = pd.DataFrame([249962,448780,499322], columns=['Second_Winning_prize'])
print(type(df_SecondPrize100))
df_SecondPrize100["Draw_Num"] = 100
new_dff2ndPrizetill100 = pd.concat([new_dff2ndPrize, df_SecondPrize100])
new_dff2ndPrizetill100
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Second_Winning_prize  Draw_Num
# 0                204763       102
# 1                413549       102
# 2                992747       102
# 0                317904       101
# 1                496553       101
# 2                800663       101
# 0                249962       100
# 1                448780       100
# 2                499322       100

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([871778], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 100
new_dff1stprizetill100 = pd.concat([new_dff1stprize, df_1st_temp])
new_dff1stprizetill100
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 0               271541       101
# 0               871778       100

# %%
"""
newdfff
new_dff2ndPrizetill100
new_dff1stprizetill100
"""
# Out:
# '\nnewdfff\nnew_dff2ndPrizetill100\nnew_dff1stprizetill100\n'

# %%
new_dfff
# Out:
#      NEW_COL  Draw_Num
# 0     0670.0       102
# 1     000nan       102
# 2     2057.0       102
# 3     2107.0       102
# 4     2566.0       102
# ...      ...       ...
# 1691  998540       100
# 1692  999276       100
# 1693  999552       100
# 1694  999599       100
# 1695  999788       100
#
# [5088 rows x 2 columns]

# %%
df_99_3rd=pd.read_csv('99-draw-3rd.csv',header=None)
df_99_3rd
# Out:
#           0       1       2       3
# 0       318    1779    2363    2413
# 1      2420    2579    3349    4131
# 2      4726    5980    6565    7350
# 3      7524    9068    9120    9895
# 4     10776   10782   10871   12055
# ..      ...     ...     ...     ...
# 419  989400  989833  990299  990539
# 420  990918  991390  991439  991715
# 421  991813  992148  992729  992928
# 422  996311  996900  997397  997648
# 423  997698  998129  999349  999427
#
# [424 rows x 4 columns]

# %%
array4 = df_99_3rd.to_numpy().flatten()
df_4= pd.DataFrame(array4)
df_4
# Out:
#            0
# 0        318
# 1       1779
# 2       2363
# 3       2413
# 4       2420
# ...      ...
# 1691  997648
# 1692  997698
# 1693  998129
# 1694  999349
# 1695  999427
#
# [1696 rows x 1 columns]

# %%
df_4
# Out:
#            0
# 0        318
# 1       1779
# 2       2363
# 3       2413
# 4       2420
# ...      ...
# 1691  997648
# 1692  997698
# 1693  998129
# 1694  999349
# 1695  999427
#
# [1696 rows x 1 columns]

# %%
df_4[0] = df_4[0].astype(str)

# %%
lst = []
for i in df_4[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_4["NEW_COL"]=lst

# %%
df_4.drop(columns=[0],inplace=True,axis=1)

# %%
df_4
# Out:
#      NEW_COL
# 0     000318
# 1     001779
# 2     002363
# 3     002413
# 4     002420
# ...      ...
# 1691  997648
# 1692  997698
# 1693  998129
# 1694  999349
# 1695  999427
#
# [1696 rows x 1 columns]

# %%
df_4["Draw_Num"] = 99

# %%
latest = pd.concat([new_dfff, df_4]).reset_index(drop=True)
latest.tail(10)
# Out:
#      NEW_COL  Draw_Num
# 6774  992729        99
# 6775  992928        99
# 6776  996311        99
# 6777  996900        99
# 6778  997397        99
# 6779  997648        99
# 6780  997698        99
# 6781  998129        99
# 6782  999349        99
# 6783  999427        99

# %%
# Process 2nd prize
df_SecondPrize99 = pd.DataFrame([462355,565416,900097], columns=['Second_Winning_prize'])
print(type(df_SecondPrize99))
df_SecondPrize99["Draw_Num"] = 99
latest_2nd_prize = pd.concat([new_dff2ndPrizetill100, df_SecondPrize99])
latest_2nd_prize=latest_2nd_prize.reset_index(drop=True)
latest_2nd_prize
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Second_Winning_prize  Draw_Num
# 0                 204763       102
# 1                 413549       102
# 2                 992747       102
# 3                 317904       101
# 4                 496553       101
# 5                 800663       101
# 6                 249962       100
# 7                 448780       100
# 8                 499322       100
# 9                 462355        99
# 10                565416        99
# 11                900097        99

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([827399], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 99
latest_1st_prize = pd.concat([new_dff1stprizetill100, df_1st_temp]).reset_index(drop=True)
latest_1st_prize
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 1               271541       101
# 2               871778       100
# 3               827399        99

# %%
"""
latest
latest_2nd_prize
latest_1st_prize
"""
# Out:
# '\nlatest\nlatest_2nd_prize\nlatest_1st_prize\n'

# %%
df_98_3rd=pd.read_csv('98-3rd.csv',header=None)
df_98_3rd
# Out:
#           0       1       2       3
# 0       974    1057    1253    1464
# 1      2211    2350    3141    3579
# 2      4115    4193    5433    7567
# 3      8320    8658    8778    9046
# 4      9772   10113   10747   11153
# ..      ...     ...     ...     ...
# 419  988669  988757  988764  989951
# 420  990136  991493  991571  993410
# 421  993548  993650  993809  994746
# 422  994803  995886  996819  996836
# 423  996883  997012  998029  999106
#
# [424 rows x 4 columns]

# %%
array5 = df_98_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
# Out:
#            0
# 0        974
# 1       1057
# 2       1253
# 3       1464
# 4       2211
# ...      ...
# 1691  996836
# 1692  996883
# 1693  997012
# 1694  998029
# 1695  999106
#
# [1696 rows x 1 columns]

# %%
df_5[0] = df_5[0].astype(str)

# %%
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst

# %%
df_5.drop(columns=[0],inplace=True,axis=1)

# %%
df_5["Draw_Num"] = 98

# %%
latest3rd = pd.concat([latest, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Out:
#      NEW_COL  Draw_Num
# 8470  993809        98
# 8471  994746        98
# 8472  994803        98
# 8473  995886        98
# 8474  996819        98
# 8475  996836        98
# 8476  996883        98
# 8477  997012        98
# 8478  998029        98
# 8479  999106        98

# %%
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([134617,197462,314256], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 98
latest_2nd_prize_l = pd.concat([latest_2nd_prize, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Second_Winning_prize  Draw_Num
# 0                 204763       102
# 1                 413549       102
# 2                 992747       102
# 3                 317904       101
# 4                 496553       101
# 5                 800663       101
# 6                 249962       100
# 7                 448780       100
# 8                 499322       100
# 9                 462355        99
# 10                565416        99
# 11                900097        99
# 12                134617        98
# 13                197462        98
# 14                314256        98

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([900286], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 98
latest_1st_prize_1 = pd.concat([latest_1st_prize, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 1               271541       101
# 2               871778       100
# 3               827399        99
# 4               900286        98

# %%
"""
latest3rd
latest_2nd_prize_l
latest_1st_prize_1
"""
# Out:
# '\nlatest3rd\nlatest_2nd_prize_l\nlatest_1st_prize_1\n'

# %%
df_97_3rd=pd.read_csv('97-3rd.csv',header=None)
df_97_3rd
# Out:
#           0       1       2       3
# 0       553     567    2271    2717
# 1      2881    3041    3451    5258
# 2      7363    7477    7503    7879
# 3      8377    9717   11410   11539
# 4     11956   13679   14117   14216
# ..      ...     ...     ...     ...
# 419  989707  990131  990733  991372
# 420  991727  992292  992787  993140
# 421  993687  994243  994387  994471
# 422  995087  995916  996040  997084
# 423  997392  997983  998358  999538
#
# [424 rows x 4 columns]

# %%
array5 = df_97_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
# Out:
#            0
# 0        553
# 1        567
# 2       2271
# 3       2717
# 4       2881
# ...      ...
# 1691  997084
# 1692  997392
# 1693  997983
# 1694  998358
# 1695  999538
#
# [1696 rows x 1 columns]

# %%
df_5[0] = df_5[0].astype(str)

# %%
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst

# %%
df_5.drop(columns=[0],inplace=True,axis=1)

# %%
df_5["Draw_Num"] = 97

# %%
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.head(10)
# Out:
#   NEW_COL  Draw_Num
# 0  0670.0       102
# 1  000nan       102
# 2  2057.0       102
# 3  2107.0       102
# 4  2566.0       102
# 5  3380.0       102
# 6  4049.0       102
# 7  4228.0       102
# 8  4323.0       102
# 9  4479.0       102

# %%
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([87220,826748,892829], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 97
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Second_Winning_prize  Draw_Num
# 0                 204763       102
# 1                 413549       102
# 2                 992747       102
# 3                 317904       101
# 4                 496553       101
# 5                 800663       101
# 6                 249962       100
# 7                 448780       100
# 8                 499322       100
# 9                 462355        99
# 10                565416        99
# 11                900097        99
# 12                134617        98
# 13                197462        98
# 14                314256        98
# 15                 87220        97
# 16                826748        97
# 17                892829        97

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([59936], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 97
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 1               271541       101
# 2               871778       100
# 3               827399        99
# 4               900286        98
# 5                59936        97

# %%
"""
latest3rd
latest_2nd_prize_l
latest_1st_prize_1
"""
# Out:
# '\nlatest3rd\nlatest_2nd_prize_l\nlatest_1st_prize_1\n'

# %%
df_96_3rd=pd.read_csv('96-3rd.csv',header=None)
df_96_3rd
# Out:
#           0       1       2       3
# 0       224     340     387    1561
# 1      1686    1978    2342    2387
# 2      3784    4024    4049    5265
# 3      5431    5529    6020    6818
# 4      7680    8300   11053   11715
# ..      ...     ...     ...     ...
# 419  987481  987539  988508  988820
# 420  990900  992602  993086  993289
# 421  993348  994035  994908  995163
# 422  996664  998260  998700  999029
# 423  999072  999301  999580  999739
#
# [424 rows x 4 columns]

# %%
array5 = df_96_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
# Out:
#            0
# 0        224
# 1        340
# 2        387
# 3       1561
# 4       1686
# ...      ...
# 1691  999029
# 1692  999072
# 1693  999301
# 1694  999580
# 1695  999739
#
# [1696 rows x 1 columns]

# %%
df_5[0] = df_5[0].astype(str)

# %%
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst

# %%
df_5.drop(columns=[0],inplace=True,axis=1)

# %%
df_5["Draw_Num"] = 96

# %%
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Out:
#       NEW_COL  Draw_Num
# 11862  994908        96
# 11863  995163        96
# 11864  996664        96
# 11865  998260        96
# 11866  998700        96
# 11867  999029        96
# 11868  999072        96
# 11869  999301        96
# 11870  999580        96
# 11871  999739        96

# %%
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([513366,827500,894418], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 96
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Second_Winning_prize  Draw_Num
# 0                 204763       102
# 1                 413549       102
# 2                 992747       102
# 3                 317904       101
# 4                 496553       101
# 5                 800663       101
# 6                 249962       100
# 7                 448780       100
# 8                 499322       100
# 9                 462355        99
# 10                565416        99
# 11                900097        99
# 12                134617        98
# 13                197462        98
# 14                314256        98
# 15                 87220        97
# 16                826748        97
# 17                892829        97
# 18                513366        96
# 19                827500        96
# 20                894418        96

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([593831], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 96
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 1               271541       101
# 2               871778       100
# 3               827399        99
# 4               900286        98
# 5                59936        97
# 6               593831        96

# %%
df_95_3rd=pd.read_csv('95-3rd.csv',header=None)
df_95_3rd
# Out:
#           0       1       2       3
# 0       752    1168    1344    2390
# 1      3345    3979    4688    5041
# 2      5157    5353    5405    6129
# 3      6706    6839    7740    9062
# 4     10074   10573   10810   11294
# ..      ...     ...     ...     ...
# 419  990047  991188  991285  992851
# 420  992949  993097  994009  994460
# 421  995415  995655  995915  996124
# 422  997225  998035  998149  998687
# 423  998939  999729  999853  999915
#
# [424 rows x 4 columns]

# %%
array5 = df_95_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
# Out:
#            0
# 0        752
# 1       1168
# 2       1344
# 3       2390
# 4       3345
# ...      ...
# 1691  998687
# 1692  998939
# 1693  999729
# 1694  999853
# 1695  999915
#
# [1696 rows x 1 columns]

# %%
df_5[0] = df_5[0].astype(str)

# %%
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst

# %%
df_5.drop(columns=[0],inplace=True,axis=1)

# %%
df_5["Draw_Num"] = 95

# %%
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.head(10)
# Out:
#   NEW_COL  Draw_Num
# 0  0670.0       102
# 1  000nan       102
# 2  2057.0       102
# 3  2107.0       102
# 4  2566.0       102
# 5  3380.0       102
# 6  4049.0       102
# 7  4228.0       102
# 8  4323.0       102
# 9  4479.0       102

# %%
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([81180,232448,747494], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 95
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Second_Winning_prize  Draw_Num
# 0                 204763       102
# 1                 413549       102
# 2                 992747       102
# 3                 317904       101
# 4                 496553       101
# 5                 800663       101
# 6                 249962       100
# 7                 448780       100
# 8                 499322       100
# 9                 462355        99
# 10                565416        99
# 11                900097        99
# 12                134617        98
# 13                197462        98
# 14                314256        98
# 15                 87220        97
# 16                826748        97
# 17                892829        97
# 18                513366        96
# 19                827500        96
# 20                894418        96
# 21                 81180        95
# 22                232448        95
# 23                747494        95

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([355591], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 95
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 1               271541       101
# 2               871778       100
# 3               827399        99
# 4               900286        98
# 5                59936        97
# 6               593831        96
# 7               355591        95

# %%
df_94_3rd=pd.read_csv('94-3rd.csv',header=None)
df_94_3rd
# Out:
#           0       1       2       3
# 0       295     315    1067    1295
# 1      1479    2266    4313    4890
# 2      5339    5366    5524    6537
# 3      6770    7823    8043    8129
# 4      8442    8913   11611   12354
# ..      ...     ...     ...     ...
# 419  991658  993538  993569  993630
# 420  993718  993749  993786  993953
# 421  994016  994205  994426  995166
# 422  995203  996492  996774  997395
# 423  998024  998442  999303  999546
#
# [424 rows x 4 columns]

# %%
array5 = df_94_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
# Out:
#            0
# 0        295
# 1        315
# 2       1067
# 3       1295
# 4       1479
# ...      ...
# 1691  997395
# 1692  998024
# 1693  998442
# 1694  999303
# 1695  999546
#
# [1696 rows x 1 columns]

# %%
df_5[0] = df_5[0].astype(str)

# %%
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst

# %%
df_5.drop(columns=[0],inplace=True,axis=1)

# %%
df_5["Draw_Num"] = 94

# %%
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Out:
#       NEW_COL  Draw_Num
# 15254  994426        94
# 15255  995166        94
# 15256  995203        94
# 15257  996492        94
# 15258  996774        94
# 15259  997395        94
# 15260  998024        94
# 15261  998442        94
# 15262  999303        94
# 15263  999546        94

# %%
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([79943,428117,608818], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 94
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Second_Winning_prize  Draw_Num
# 0                 204763       102
# 1                 413549       102
# 2                 992747       102
# 3                 317904       101
# 4                 496553       101
# 5                 800663       101
# 6                 249962       100
# 7                 448780       100
# 8                 499322       100
# 9                 462355        99
# 10                565416        99
# 11                900097        99
# 12                134617        98
# 13                197462        98
# 14                314256        98
# 15                 87220        97
# 16                826748        97
# 17                892829        97
# 18                513366        96
# 19                827500        96
# 20                894418        96
# 21                 81180        95
# 22                232448        95
# 23                747494        95
# ...

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([544692], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 94
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 1               271541       101
# 2               871778       100
# 3               827399        99
# 4               900286        98
# 5                59936        97
# 6               593831        96
# 7               355591        95
# 8               544692        94

# %%
df_93_3rd=pd.read_csv('93-3rd.csv',header=None)
df_93_3rd
# Out:
#           0       1       2       3
# 0       693    1288    1421    1647
# 1      1695    2087    2628    2786
# 2      2788    5208    6937    7887
# 3      9505    9653    9906    9978
# 4     10300   11400   12839   13080
# ..      ...     ...     ...     ...
# 419  992668  992717  992840  992886
# 420  993870  993939  994110  994379
# 421  994949  996378  996755  997135
# 422  997538  997659  997733  998471
# 423  998792  998879  999184  999571
#
# [424 rows x 4 columns]

# %%
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
# Out:
#            0
# 0        693
# 1       1288
# 2       1421
# 3       1647
# 4       1695
# ...      ...
# 1691  998471
# 1692  998792
# 1693  998879
# 1694  999184
# 1695  999571
#
# [1696 rows x 1 columns]

# %%
df_5[0] = df_5[0].astype(str)

# %%
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)

# %%
df_5["Draw_Num"] = 93

# %%
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Out:
#       NEW_COL  Draw_Num
# 16950  996755        93
# 16951  997135        93
# 16952  997538        93
# 16953  997659        93
# 16954  997733        93
# 16955  998471        93
# 16956  998792        93
# 16957  998879        93
# 16958  999184        93
# 16959  999571        93

# %%
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([546784,580518,765113], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 93
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Second_Winning_prize  Draw_Num
# 0                 204763       102
# 1                 413549       102
# 2                 992747       102
# 3                 317904       101
# 4                 496553       101
# 5                 800663       101
# 6                 249962       100
# 7                 448780       100
# 8                 499322       100
# 9                 462355        99
# 10                565416        99
# 11                900097        99
# 12                134617        98
# 13                197462        98
# 14                314256        98
# 15                 87220        97
# 16                826748        97
# 17                892829        97
# 18                513366        96
# 19                827500        96
# 20                894418        96
# 21                 81180        95
# 22                232448        95
# 23                747494        95
# ...

# %%
# Process 1st prize
df_1st_temp = pd.DataFrame([24128], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 93
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First_Winning_Prize  Draw_Num
# 0               261227       102
# 1               271541       101
# 2               871778       100
# 3               827399        99
# 4               900286        98
# 5                59936        97
# 6               593831        96
# 7               355591        95
# 8               544692        94
# 9                24128        93

# %%
df_93_3rd=pd.read_csv('92-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 92
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([203689,317910,598900], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 92
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([141795], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 92
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92

# %%
df_93_3rd=pd.read_csv('91-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 91
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([321896,828159,873786], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 91
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([722561], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 91
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91

# %%
"5:18"
# Out:
# '5:18'

# %%
import datetime
now = datetime.datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 15:04:28

# %%
df_93_3rd=pd.read_csv('90-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 90
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([207865,529894,829039], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 90
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([394635], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 90
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90

# %%
df_93_3rd=pd.read_csv('89-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 89
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([511294,549996,983274], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 89
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([4208], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 89
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89

# %%
df_93_3rd=pd.read_csv('88-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 88
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([172166,321134,828622], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 88
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([69845], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 88
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88

# %%
df_93_3rd=pd.read_csv('87-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 87
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([232705,842723,908062], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 87
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([331809], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 87
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87

# %%
df_93_3rd=pd.read_csv('86-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 86
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([831,314705,417508], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 86
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([38012], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 86
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86

# %%
df_93_3rd=pd.read_csv('85-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 85
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([194668,871860,953604], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 85
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([217739], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 85
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85

# %%
df_93_3rd=pd.read_csv('84-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 84
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([44848,168263,728072], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 84
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([854741], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 84
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84

# %%
df_93_3rd=pd.read_csv('83-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 83
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([394067,603610,930253], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 83
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([308857], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 83
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84
# 19               308857        83

# %%
df_93_3rd=pd.read_csv('82-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 82
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([48813,266370,662748], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 82
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([253534], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 82
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84
# 19               308857        83
# 20               253534        82

# %%
df_93_3rd=pd.read_csv('81-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 81
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([515888,558129,943879], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 81
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([958892], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 81
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84
# 19               308857        83
# 20               253534        82
# 21               958892        81

# %%
"""HELLO"""
# Out:
# 'HELLO'

# %%
df_93_3rd=pd.read_csv('80-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 80
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([296432,512602,813469], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 80
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([378562], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 80
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84
# 19               308857        83
# 20               253534        82
# 21               958892        81
# 22               378562        80

# %%
df_93_3rd=pd.read_csv('79-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 79
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([204877,262276,619632], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 79
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([161158], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 79
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84
# 19               308857        83
# 20               253534        82
# 21               958892        81
# 22               378562        80
# 23               161158        79

# %%
df_93_3rd=pd.read_csv('78-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 78
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([3875,663603,983623], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 78
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([682299], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 78
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84
# 19               308857        83
# 20               253534        82
# 21               958892        81
# 22               378562        80
# 23               161158        79
# ...

# %%
df_93_3rd=pd.read_csv('77-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 77
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([121611,223172,553151], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 77
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([479780], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 77
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#     First_Winning_Prize  Draw_Num
# 0                261227       102
# 1                271541       101
# 2                871778       100
# 3                827399        99
# 4                900286        98
# 5                 59936        97
# 6                593831        96
# 7                355591        95
# 8                544692        94
# 9                 24128        93
# 10               141795        92
# 11               722561        91
# 12               394635        90
# 13                 4208        89
# 14                69845        88
# 15               331809        87
# 16                38012        86
# 17               217739        85
# 18               854741        84
# 19               308857        83
# 20               253534        82
# 21               958892        81
# 22               378562        80
# 23               161158        79
# ...

# %%
df_93_3rd=pd.read_csv('76-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 76
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([96651,678838,835627], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 76
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([963916], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 76
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1

# %%
df_93_3rd=pd.read_csv('75-3rd.csv',header=None)
df_93_3rd
array5 = df_93_3rd.to_numpy().flatten()
df_5= pd.DataFrame(array5)
df_5
df_5[0] = df_5[0].astype(str)
lst = []
for i in df_5[0]:
    while len(i) < 6:
        i = "0" + i  # Reassign the modified string to i
    lst.append(i)

df_5["NEW_COL"]=lst
df_5.drop(columns=[0],inplace=True,axis=1)
df_5["Draw_Num"] = 75
latest3rd = pd.concat([latest3rd, df_5]).reset_index(drop=True)
latest3rd.tail(10)
# Process 2nd prize
df_SecondPrize98 = pd.DataFrame([6662,554796,958183], columns=['Second_Winning_prize'])
print(type(df_SecondPrize98))
df_SecondPrize98["Draw_Num"] = 75
latest_2nd_prize_l = pd.concat([latest_2nd_prize_l, df_SecondPrize98])
latest_2nd_prize_l=latest_2nd_prize_l.reset_index(drop=True)
latest_2nd_prize_l
# Process 1st prize
df_1st_temp = pd.DataFrame([374125], columns=['First_Winning_Prize'])
print(type(df_1st_temp))
df_1st_temp["Draw_Num"] = 75
latest_1st_prize_1 = pd.concat([latest_1st_prize_1, df_1st_temp]).reset_index(drop=True)
latest_1st_prize_1
